# %% [markdown]
# # Environment

# %% [markdown]
# ## Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import scanpy as sc
import anndata as an

import muon as mu
from muon import atac as ac
# Out:
# /lustre/scratch124/cellgen/cellgeni/aljes/compare-peaks/.venv/lib/python3.13/site-packages/muon/_core/preproc.py:31: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   if Version(scanpy.__version__) < Version("1.10"):

# %% [markdown]
# ## Global variables

# %% [markdown]
# ## Load data

# %%
adata = sc.read_h5ad("results/pseudobulk/lvl3/combined.h5ad")
adata.layers["sum"] = np.nan_to_num(adata.layers["sum"], nan=0)
adata.layers["mean"] = np.nan_to_num(adata.layers["mean"], nan=0)
adata
# Out:
# AnnData object with n_obs × n_vars = 2074 × 966824
#     obs: 'sample_id', 'celltype', 'n_obs_aggregated'
#     layers: 'mean', 'sum'

# %% [markdown]
# # Process

# %% [markdown]
# ## QC

# %%
sns.histplot(adata.obs.n_obs_aggregated)
# Out:
# <Axes: xlabel='n_obs_aggregated', ylabel='Count'>

# %% [markdown]
# Add total counts per cell and per peak

# %%
adata.obs["total_counts_sum"] = adata.layers["sum"].sum(axis=1)
adata.obs["total_counts_mean"] = adata.layers["mean"].sum(axis=1)

adata.var["total_counts_sum"] = adata.layers["sum"].sum(axis=0)
adata.var["total_counts_mean"] = adata.layers["mean"].sum(axis=0)
adata
# Out:
# AnnData object with n_obs × n_vars = 2074 × 966824
#     obs: 'sample_id', 'celltype', 'n_obs_aggregated', 'total_counts_sum', 'total_counts_mean'
#     var: 'total_counts_sum', 'total_counts_mean'
#     layers: 'mean', 'sum'

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.histplot(np.log1p(adata.var.total_counts_sum), ax=axes[0, 0])
sns.histplot(np.log1p(adata.var.total_counts_mean), ax=axes[0, 1])
axes[0, 0].set_title("Total counts per peak (sum)")
axes[0, 1].set_title("Total counts per peak (mean)")

sns.histplot(np.log1p(adata.obs.total_counts_sum), ax=axes[1, 0])
sns.histplot(np.log1p(adata.obs.total_counts_mean), ax=axes[1, 1])
axes[1, 0].set_title("Total counts per sample (sum)")
axes[1, 1].set_title("Total counts per sample (mean)")

plt.tight_layout()

# %% [markdown]
# Let's filter pseudobulk samples with less than 20 cells aggregated, as these are likely to be noisy

# %%
before_filtering = adata.obs.groupby("celltype").agg({"n_obs_aggregated": ["sum", "count"]})
before_filtering.columns = ["total_cells", "n_pb_samples"]

filtered = adata[adata.obs.n_obs_aggregated < 5].obs.groupby("celltype").agg({"n_obs_aggregated": ["sum", "count"]})
filtered.columns = ["total_cells_filtered", "n_pb_samples_filtered"]

summary = before_filtering.join(filtered, how="left").fillna(0)
summary["percent_cells_filtered"] = np.round(summary["total_cells_filtered"] / summary["total_cells"] * 100, 2)
summary["percent_samples_filtered"] = np.round(summary["n_pb_samples_filtered"] / summary["n_pb_samples"] * 100, 2)
summary.sort_values("percent_samples_filtered", ascending=False)
# Out:
# /tmp/ipykernel_3090356/1706020334.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   before_filtering = adata.obs.groupby("celltype").agg({"n_obs_aggregated": ["sum", "count"]})
# /tmp/ipykernel_3090356/1706020334.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filtered = adata[adata.obs.n_obs_aggregated < 5].obs.groupby("celltype").agg({"n_obs_aggregated": ["sum", "count"]})
#                                     total_cells  n_pb_samples  \
# celltype
# haematopoietic progenitors                  123            16
# primordial germ cell                         24             6
# lymphoid cells                              770            51
# liver                                      1626            27
# pancreatic                                 1981            29
# audiovisual neuroepithelium                2054            38
# epicardium                                 6912            42
# perimysium                                 2443            38
# gonadal                                    2954            33
# craniofacial                               5820            34
# renal                                      6641            41
# lung                                        645            48
# intestinal                                  700            27
# neurons - inhibitory                       1658            44
# myocardium                                 6013            41
# paraxial mesoderm                         17412            41
# intermediate mesoderm                      9897            44
# neurons - serotonergic                     1186            44
# limb chondrocytes                          6360            33
# oesophageal                                1578            44
# osteochondral                              7772            47
# lateral plate mesoderm                    12914            48
# limb mesenchyme                           28082            52
# neural progenitors - IPC                   4368            46
# stomach                                    7683            54
# splanchnic mesoderm                        7267            46
# pharyngeal                                15888            50
# glia - NCC-SCPs                            9042            51
# neurons - ELAVL4+                         20562            56
# tendons                                    7625            49
# mural                                     12866            54
# skeletal muscle                           13227            43
# neural progenitors - neural tube          10499            45
# spine                                      9288            51
# epidermis                                  3040            56
# neurons - excitatory                       5872            47
# glia - neural tube                         9780            47
# fibroblasts                               16183            56
# endothelium                                5158            56
# glia - pre-OPC                             9144            47
# neurons - dopaminergic                     4961            47
# neural progenitors - NEUROG1+              4046            47
# myeloid cells                              4372            56
# mast megakaryocyte erythroid cells         5405            56
# neural progenitors - radial glia          35198            47
# neurons - peripheral                       3779            52
# neurons - neural tube                     13088            47
#
#                                     total_cells_filtered  \
# celltype
# haematopoietic progenitors                          13.0
# primordial germ cell                                 9.0
# lymphoid cells                                      75.0
# liver                                               35.0
# pancreatic                                          25.0
# audiovisual neuroepithelium                         40.0
# epicardium                                          34.0
# perimysium                                          29.0
# gonadal                                             10.0
# craniofacial                                        14.0
# renal                                               20.0
# lung                                                32.0
# intestinal                                          16.0
# neurons - inhibitory                                29.0
# myocardium                                          22.0
# paraxial mesoderm                                   19.0
# intermediate mesoderm                               17.0
# neurons - serotonergic                              18.0
# limb chondrocytes                                   10.0
# oesophageal                                         10.0
# osteochondral                                       16.0
# lateral plate mesoderm                              14.0
# limb mesenchyme                                     12.0
# neural progenitors - IPC                            11.0
# stomach                                              8.0
# splanchnic mesoderm                                  8.0
# pharyngeal                                           8.0
# glia - NCC-SCPs                                     11.0
# neurons - ELAVL4+                                   13.0
# tendons                                              4.0
# mural                                                6.0
# skeletal muscle                                      3.0
# neural progenitors - neural tube                     5.0
# spine                                                5.0
# epidermis                                            6.0
# neurons - excitatory                                 2.0
# glia - neural tube                                   3.0
# fibroblasts                                          3.0
# endothelium                                          0.0
# glia - pre-OPC                                       0.0
# neurons - dopaminergic                               0.0
# neural progenitors - NEUROG1+                        0.0
# myeloid cells                                        0.0
# mast megakaryocyte erythroid cells                   0.0
# neural progenitors - radial glia                     0.0
# neurons - peripheral                                 0.0
# neurons - neural tube                                0.0
#
#                                     n_pb_samples_filtered  \
# celltype
# haematopoietic progenitors                           12.0
# primordial germ cell                                  4.0
# lymphoid cells                                       33.0
# liver                                                17.0
# pancreatic                                           17.0
# audiovisual neuroepithelium                          18.0
# epicardium                                           15.0
# perimysium                                           12.0
# gonadal                                              10.0
# craniofacial                                         10.0
# renal                                                12.0
# lung                                                 13.0
# intestinal                                            7.0
# neurons - inhibitory                                 11.0
# myocardium                                           10.0
# paraxial mesoderm                                    10.0
# intermediate mesoderm                                 9.0
# neurons - serotonergic                                8.0
# limb chondrocytes                                     6.0
# oesophageal                                           7.0
# osteochondral                                         7.0
# lateral plate mesoderm                                6.0
# limb mesenchyme                                       6.0
# neural progenitors - IPC                              5.0
# stomach                                               5.0
# splanchnic mesoderm                                   4.0
# pharyngeal                                            4.0
# glia - NCC-SCPs                                       4.0
# neurons - ELAVL4+                                     4.0
# tendons                                               3.0
# mural                                                 3.0
# skeletal muscle                                       2.0
# neural progenitors - neural tube                      2.0
# spine                                                 2.0
# epidermis                                             2.0
# neurons - excitatory                                  1.0
# glia - neural tube                                    1.0
# fibroblasts                                           1.0
# endothelium                                           0.0
# glia - pre-OPC                                        0.0
# neurons - dopaminergic                                0.0
# neural progenitors - NEUROG1+                         0.0
# myeloid cells                                         0.0
# mast megakaryocyte erythroid cells                    0.0
# neural progenitors - radial glia                      0.0
# neurons - peripheral                                  0.0
# neurons - neural tube                                 0.0
#
#                                     percent_cells_filtered  \
# celltype
# haematopoietic progenitors                           10.57
# primordial germ cell                                 37.50
# lymphoid cells                                        9.74
# liver                                                 2.15
# pancreatic                                            1.26
# audiovisual neuroepithelium                           1.95
# epicardium                                            0.49
# perimysium                                            1.19
# gonadal                                               0.34
# craniofacial                                          0.24
# renal                                                 0.30
# lung                                                  4.96
# intestinal                                            2.29
# neurons - inhibitory                                  1.75
# myocardium                                            0.37
# paraxial mesoderm                                     0.11
# intermediate mesoderm                                 0.17
# neurons - serotonergic                                1.52
# limb chondrocytes                                     0.16
# oesophageal                                           0.63
# osteochondral                                         0.21
# lateral plate mesoderm                                0.11
# limb mesenchyme                                       0.04
# neural progenitors - IPC                              0.25
# stomach                                               0.10
# splanchnic mesoderm                                   0.11
# pharyngeal                                            0.05
# glia - NCC-SCPs                                       0.12
# neurons - ELAVL4+                                     0.06
# tendons                                               0.05
# mural                                                 0.05
# skeletal muscle                                       0.02
# neural progenitors - neural tube                      0.05
# spine                                                 0.05
# epidermis                                             0.20
# neurons - excitatory                                  0.03
# glia - neural tube                                    0.03
# fibroblasts                                           0.02
# endothelium                                           0.00
# glia - pre-OPC                                        0.00
# neurons - dopaminergic                                0.00
# neural progenitors - NEUROG1+                         0.00
# myeloid cells                                         0.00
# mast megakaryocyte erythroid cells                    0.00
# neural progenitors - radial glia                      0.00
# neurons - peripheral                                  0.00
# neurons - neural tube                                 0.00
#
#                                     percent_samples_filtered
# celltype
# haematopoietic progenitors                             75.00
# primordial germ cell                                   66.67
# lymphoid cells                                         64.71
# liver                                                  62.96
# pancreatic                                             58.62
# audiovisual neuroepithelium                            47.37
# epicardium                                             35.71
# perimysium                                             31.58
# gonadal                                                30.30
# craniofacial                                           29.41
# renal                                                  29.27
# lung                                                   27.08
# intestinal                                             25.93
# neurons - inhibitory                                   25.00
# myocardium                                             24.39
# paraxial mesoderm                                      24.39
# intermediate mesoderm                                  20.45
# neurons - serotonergic                                 18.18
# limb chondrocytes                                      18.18
# oesophageal                                            15.91
# osteochondral                                          14.89
# lateral plate mesoderm                                 12.50
# limb mesenchyme                                        11.54
# neural progenitors - IPC                               10.87
# stomach                                                 9.26
# splanchnic mesoderm                                     8.70
# pharyngeal                                              8.00
# glia - NCC-SCPs                                         7.84
# neurons - ELAVL4+                                       7.14
# tendons                                                 6.12
# mural                                                   5.56
# skeletal muscle                                         4.65
# neural progenitors - neural tube                        4.44
# spine                                                   3.92
# epidermis                                               3.57
# neurons - excitatory                                    2.13
# glia - neural tube                                      2.13
# fibroblasts                                             1.79
# endothelium                                             0.00
# glia - pre-OPC                                          0.00
# neurons - dopaminergic                                  0.00
# neural progenitors - NEUROG1+                           0.00
# myeloid cells                                           0.00
# mast megakaryocyte erythroid cells                      0.00
# neural progenitors - radial glia                        0.00
# neurons - peripheral                                    0.00
# neurons - neural tube                                   0.00

# %%
print(f"Number of pseudobulk samples filtered: {((adata.obs.n_obs_aggregated < 5) & ~(adata.obs.celltype.isin(["haematopoietic progenitors", "primordial germ cell"]))).sum()}")
adata = adata[(adata.obs.n_obs_aggregated >= 5) | (adata.obs.celltype.isin(["haematopoietic progenitors", "primordial germ cell"]))].copy()
adata
# Out:
# Number of pseudobulk samples filtered: 287
# AnnData object with n_obs × n_vars = 1787 × 966824
#     obs: 'sample_id', 'celltype', 'n_obs_aggregated', 'total_counts_sum', 'total_counts_mean'
#     var: 'total_counts_sum', 'total_counts_mean'
#     layers: 'mean', 'sum'

# %% [markdown]
# ## Highly variable peaks

# %% [markdown]
# Normalise for sequence depth and log-transform

# %%
adata.layers["log_normsum"] = adata.layers["sum"].copy()
sc.pp.normalize_total(adata, target_sum=1e4, layer="log_normsum")
sc.pp.log1p(adata, layer="log_normsum")

# %%
adata.layers["log_normmean"] = adata.layers["mean"].copy()
sc.pp.normalize_total(adata, target_sum=1e4, layer="log_normmean")
sc.pp.log1p(adata, layer="log_normmean")
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
sc.pp.highly_variable_genes(adata, layer="log_normsum", flavor="seurat")
adata_hv_sum = adata[:, adata.var.highly_variable].copy()
adata_hv_sum
# Out:
# AnnData object with n_obs × n_vars = 1787 × 41680
#     obs: 'sample_id', 'celltype', 'n_obs_aggregated', 'total_counts_sum', 'total_counts_mean'
#     var: 'total_counts_sum', 'total_counts_mean', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'
#     layers: 'mean', 'sum', 'log_normsum', 'log_normmean'

# %%
sc.pp.highly_variable_genes(adata, layer="log_normmean", flavor="seurat")
adata_hv_mean = adata[:, adata.var.highly_variable].copy()
adata_hv_mean
# Out:
# AnnData object with n_obs × n_vars = 1787 × 41680
#     obs: 'sample_id', 'celltype', 'n_obs_aggregated', 'total_counts_sum', 'total_counts_mean'
#     var: 'total_counts_sum', 'total_counts_mean', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'
#     layers: 'mean', 'sum', 'log_normsum', 'log_normmean'

# %% [markdown]
# ## Embeddings

# %% [markdown]
# ### SUM

# %% [markdown]
# Normalise with TF-IDF

# %%
ac.pp.tfidf(adata_hv_sum, scale_factor=1e4, from_layer="sum", to_layer="tfidf_sum")

# %%
adata_hv_sum.X = adata_hv_sum.layers["tfidf_sum"]

# %% [markdown]
# Calculate LSI embedding

# %%
ac.tl.lsi(adata_hv_sum, n_comps=50)
# adata_hv_sum.obsm['X_lsi'] = adata_hv_sum.obsm['X_lsi'][:,1:]
# adata_hv_sum.varm["LSI"] = adata_hv_sum.varm["LSI"][:,1:]
# adata_hv_sum.uns["lsi"]["stdev"] = adata_hv_sum.uns["lsi"]["stdev"][1:]

# %% [markdown]
# Calculate PCA embedding

# %%
sc.pp.pca(adata_hv_sum, n_comps=50, layer="tfidf_sum")
# adata_hv_sum.obsm['pca_sum'] = adata_hv_sum.obsm['pca_sum'][:,2:]
# adata_hv_sum.varm["pca_sum"] = adata_hv_sum.varm["LSI"][:,2:]
# adata_hv_sum.uns["pca_sum"]["variance"] = adata_hv_sum.uns["pca_sum"]["variance"][2:]
# adata_hv_sum.uns["pca_sum"]["variance_ratio"] = adata_hv_sum.uns["pca_sum"]["variance_ratio"][2:]

# %% [markdown]
# Calculate KNN graphs

# %%
sc.pp.neighbors(adata_hv_sum, use_rep="X_lsi", key_added="neighbors_lsi")
sc.pp.neighbors(adata_hv_sum, use_rep="X_pca", key_added="neighbors_pca")

# %% [markdown]
# Calculate UMAP embeddings

# %%
sc.tl.umap(adata_hv_sum, neighbors_key="neighbors_lsi", key_added="umap_lsi")
sc.tl.umap(adata_hv_sum, neighbors_key="neighbors_pca", key_added="umap_pca")

# %%
sc.pl.embedding(adata_hv_sum, basis="X_pca", color=["celltype"], ncols=1, components=["1,2", "3,4"])

# %%
sc.pl.embedding(adata_hv_sum, basis="X_lsi", color=["celltype"], ncols=1, components=["1,2", "3,4"])

# %%
sc.pl.embedding(adata_hv_sum, basis="umap_pca", color=["celltype", "sample_id"], ncols=1)

# %%
sc.pl.embedding(adata_hv_sum, basis="umap_lsi", color=["celltype", "sample_id"], ncols=1)

# %% [markdown]
# ### MEAN

# %% [markdown]
# Normalise with TF-IDF

# %%
ac.pp.tfidf(adata_hv_mean, scale_factor=1e4, from_layer="mean", to_layer="tfidf_mean")

# %%
adata_hv_mean.X = adata_hv_mean.layers["tfidf_mean"]

# %% [markdown]
# Calculate LSI embedding

# %%
ac.tl.lsi(adata_hv_mean, n_comps=50)
# adata_hv_mean.obsm['X_lsi'] = adata_hv_mean.obsm['X_lsi'][:,1:]
# adata_hv_mean.varm["LSI"] = adata_hv_mean.varm["LSI"][:,1:]
# adata_hv_mean.uns["lsi"]["stdev"] = adata_hv_mean.uns["lsi"]["stdev"][1:]

# %% [markdown]
# Calculate PCA embedding

# %%
sc.pp.pca(adata_hv_mean, n_comps=50, layer="tfidf_mean")
# adata_hv_mean.obsm['pca_mean'] = adata_hv_mean.obsm['pca_mean'][:,2:]
# adata_hv_mean.varm["pca_mean"] = adata_hv_mean.varm["LSI"][:,2:]
# adata_hv_mean.uns["pca_mean"]["variance"] = adata_hv_mean.uns["pca_mean"]["variance"][2:]
# adata_hv_mean.uns["pca_mean"]["variance_ratio"] = adata_hv_mean.uns["pca_mean"]["variance_ratio"][2:]

# %% [markdown]
# Calculate KNN graphs

# %%
sc.pp.neighbors(adata_hv_mean, use_rep="X_lsi", key_added="neighbors_lsi")
sc.pp.neighbors(adata_hv_mean, use_rep="X_pca", key_added="neighbors_pca")

# %% [markdown]
# Calculate UMAP embeddings

# %%
sc.tl.umap(adata_hv_mean, neighbors_key="neighbors_lsi", key_added="umap_lsi")
sc.tl.umap(adata_hv_mean, neighbors_key="neighbors_pca", key_added="umap_pca")

# %%
sc.pl.embedding(adata_hv_mean, basis="X_pca", color=["celltype"], ncols=1, components=["1,2", "3,4"])

# %%
sc.pl.embedding(adata_hv_mean, basis="X_lsi", color=["celltype"], ncols=1, components=["1,2", "3,4"])

# %%
sc.pl.embedding(adata_hv_mean, basis="umap_pca", color=["celltype", "sample_id"], ncols=1)

# %%
sc.pl.embedding(adata_hv_mean, basis="umap_lsi", color=["celltype", "sample_id"], ncols=1)

# %% [markdown]
# # Save results

# %%
adata.write_h5ad("results/pseudobulk/lvl3/filtered.h5ad")
adata_hv_mean.write_h5ad("results/pseudobulk/lvl3/adata_hv_mean.h5ad")
adata_hv_sum.write_h5ad("results/pseudobulk/lvl3/adata_hv_sum.h5ad")
